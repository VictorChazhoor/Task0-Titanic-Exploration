# %%
#importing modules pandas and numpy
import pandas as pd
import numpy as np
import matplotlib.pyplot as pl

# %%
#loading dataset using pandas stored in variable ds
ds = pd.read_csv("train.csv")
ds
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#important information about dataset
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#Removing all rows containing null value
ds1 = ds.dropna()
ds1
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#dropping column PassengerId and Name
ds2 = ds.drop(columns=['PassengerId', 'Name'])
ds2
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    male  22.0      1      0         A/5 21171   7.2500
# 1           1       1  female  38.0      1      0          PC 17599  71.2833
# 2           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3           1       1  female  35.0      1      0            113803  53.1000
# 4           0       3    male  35.0      0      0            373450   8.0500
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 886         0       2    male  27.0      0      0            211536  13.0000
# 887         1       1  female  19.0      0      0            112053  30.0000
# 888         0       3  female   NaN      1      2        W./C. 6607  23.4500
# 889         1       1    male  26.0      0      0            111369  30.0000
# 890         0       3    male  32.0      0      0            370376   7.7500
#
#     Cabin Embarked
# 0     NaN        S
# ...

# %%
#dividing dataset in ratio 80:20
n = ds.shape[0]
n1 = int(0.8*n)+1
ds3 = ds.iloc[0:n1]
ds3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 708          709         1       1
# 709          710         1       3
# 710          711         1       1
# 711          712         0       1
# 712          713         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ds4 = ds.iloc[n1:n]
ds4
# Out:
#      PassengerId  Survived  Pclass  \
# 713          714         0       3
# 714          715         0       2
# 715          716         0       3
# 716          717         1       1
# 717          718         1       2
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 713                  Larsson, Mr. August Viktor    male  29.0      0      0
# 714                       Greenberg, Mr. Samuel    male  52.0      0      0
# 715  Soholt, Mr. Peter Andreas Lauritz Andersen    male  19.0      0      0
# 716               Endres, Miss. Caroline Louise  female  38.0      0      0
# 717         Troutt, Miss. Edwina Celia "Winnie"  female  27.0      0      0
# ..                                          ...     ...   ...    ...    ...
# ...

# %%
#Histogram for column fare
pl.hist(ds1['Fare'])
pl.title('Fare')
pl.show()

# %%
#Histogram for column age
pl.hist(ds1['Age'])
pl.title('Age')
pl.show()

# %%
#Bar Chart for Column Survived
c1 = 0
c0 = 0
for i in ds1['Survived']:
    if i:
        c1+=1
    else:
        c0+=1
x = np.array(['Deceased', 'Survived'])
y = np.array([c0, c1])
pl.bar(x, y)
pl.title('Survived Bar Chart')
pl.ylabel('No of people')
pl.show()

# %%
#Bar Chart for Column Sex
c1 = 0
c0 = 0
for i in ds1['Sex']:
    if i=='female':
        c1+=1
    else:
        c0+=1
x = np.array(['Male', 'Female'])
y = np.array([c0, c1])
pl.bar(x, y, color=['blue', 'pink'])
pl.title('Sex Bar Chart')
pl.ylabel('No of people')
pl.show()
